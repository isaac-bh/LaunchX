# %%
def main():
    try:
        archivo = open("hola")
    except FileNotFoundError:
        print("Error: No se pudo encontrar el archivo.")
    except IsADirectoryError:
        print("Error: No es un archivo, es un directorio.")
    except TimeoutError:
        print("Error: no se pudo leer correctamente el archivo.")


if __name__ == '__main__':
    main()
# Out:
# Error: No se pudo encontrar el archivo.
